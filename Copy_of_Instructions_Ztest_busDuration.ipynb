# %% [markdown]
# <a href="https://colab.research.google.com/github/himalachudel/FDSFE_HAcharya/blob/main/Copy_of_Instructions_Ztest_busDuration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Trip duration for bus Septa32 is 34 min on average (+/- 2.4).
# We wonderful city planners think we have a better route that will save time.
#
# We ask you to our Department of Transportation data scientist to tell is if after we change the route has the trip duration has changed.
#
# We have measured the duration of the trips along the new route and collected the data here https://github.com/fedhere/FDSfE_FBianco/blob/main/data/triptimes.csv
#
# # What is your Null Hypothesis?

# %%
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/main/data/triptimes.csv",names=["duration"])

# %%
data
# Out:
#      duration
# 0   31.622239
# 1   32.821376
# 2   30.229101
# 3   31.413766
# 4   39.010550
# ..        ...
# 95  26.197852
# 96  42.727410
# 97  33.731470
# 98  37.238591
# 99  36.339841
#
# [100 rows x 1 columns]

# %%
data.describe()
# Out:
#        31.62223931
# count    99.000000
# mean     34.494888
# std       7.167790
# min      16.527267
# 25%      30.018770
# 50%      34.822079
# 75%      39.626967
# max      48.749877
