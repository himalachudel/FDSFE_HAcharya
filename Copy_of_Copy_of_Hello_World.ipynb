# %% [markdown]
# <a href="https://colab.research.google.com/github/himalachudel/FDSFE_HAcharya/blob/main/Copy_of_Copy_of_Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# This was an exercise in printing Hello World in python

# %%
greeting = "Hello"
all = "World"
punct = "!"

# %%
print(greeting)
# Out:
# Hello

# %%
print(greeting, all, punct)
# Out:
# Hello World !

# %%
print(greeting, all + punct)
# Out:
# Hello World!

# %%
me = "Federica"

# %%
print(greeting, me + punct)
# Out:
# Hello Federica!

# %%
print(greeting, me + punct, sep=",")
# Out:
# Hello,Federica!

# %%
print(greeting)
# Out:
# Hello

# %%
import pandas as pd

# %%
happiness_df = pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/main/data/happines.csv")

# %%
happiness_df
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
# 158      Namibia                              NaN            4.639
# 159       Gambia                              NaN            4.516
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
videos_df = pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/main/data/USyoutubes.csv")

# %%
videos_df
# Out:
#       trending_date                                              title  \
# 0          17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1          17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2          17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3          17.14.11                   Nickelback Lyrics: Real or Fake?
# 4          17.14.11                           I Dare You: GOING BALD!?
# ...             ...                                                ...
# 40944      18.14.06                       The Cat Who Caught the Laser
# 40945      18.14.06                         True Facts : Ant Mutualism
# 40946      18.14.06  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947      18.14.06                How Black Panther Should Have Ended
# 40948      18.14.06  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# ...

# %%
videos_df.head(3)
# Out:
#   trending_date                                              title  \
# 0      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
#
#      channel_title  category_id              publish_time  \
# 0     CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1  LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2     Rudy Mancuso           23  2017-11-12T19:05:24.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
#
#    dislikes  comment_count
# 0      2966          15954
# 1      6146          12703
# 2      5339           8181

# %%
videos_df.tail(3)
# Out:
#       trending_date                                              title  \
# 40946      18.14.06  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947      18.14.06                How Black Panther Should Have Ended
# 40948      18.14.06  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count
# 40946      1032           3992
# ...

# %%
videos_df.shape
# Out:
# (40949, 10)

# %%
videos_df.columns
# Out:
# Index(['trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count'],
#       dtype='object')

# %%
videos_df['likes'].mean()
# Out:
# 74266.7024347359

# %%
videos_df.corr()
# Out:
# <ipython-input-27-6aec42e428a9>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   videos_df.corr()
#                category_id     views     likes  dislikes  comment_count
# category_id       1.000000 -0.168231 -0.173921 -0.033547      -0.076307
# views            -0.168231  1.000000  0.849177  0.472213       0.617621
# likes            -0.173921  0.849177  1.000000  0.447186       0.803057
# dislikes         -0.033547  0.472213  0.447186  1.000000       0.700184
# comment_count    -0.076307  0.617621  0.803057  0.700184       1.000000

# %%
videos_df.describe()
# Out:
#         category_id         views         likes      dislikes  comment_count
# count  40949.000000  4.094900e+04  4.094900e+04  4.094900e+04   4.094900e+04
# mean      19.972429  2.360785e+06  7.426670e+04  3.711401e+03   8.446804e+03
# std        7.568327  7.394114e+06  2.288853e+05  2.902971e+04   3.743049e+04
# min        1.000000  5.490000e+02  0.000000e+00  0.000000e+00   0.000000e+00
# 25%       17.000000  2.423290e+05  5.424000e+03  2.020000e+02   6.140000e+02
# 50%       24.000000  6.818610e+05  1.809100e+04  6.310000e+02   1.856000e+03
# 75%       25.000000  1.823157e+06  5.541700e+04  1.938000e+03   5.755000e+03
# max       43.000000  2.252119e+08  5.613827e+06  1.674420e+06   1.361580e+06

# %%
videos_df
# Out:
#       trending_date                                              title  \
# 0          17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1          17.14.11  The Trump Presidency: Last Week Tonight with J...
# 2          17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# 3          17.14.11                   Nickelback Lyrics: Real or Fake?
# 4          17.14.11                           I Dare You: GOING BALD!?
# ...             ...                                                ...
# 40944      18.14.06                       The Cat Who Caught the Laser
# 40945      18.14.06                         True Facts : Ant Mutualism
# 40946      18.14.06  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947      18.14.06                How Black Panther Should Have Ended
# 40948      18.14.06  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# ...

# %%
videos_df.columns
# Out:
# Index(['trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count'],
#       dtype='object')

# %%
videos_restrict=videos_df[['views', 'likes', 'dislikes', 'comment_count']]

# %%
videos_restrict
# Out:
#           views   likes  dislikes  comment_count
# 0        748374   57527      2966          15954
# 1       2418783   97185      6146          12703
# 2       3191434  146033      5339           8181
# 3        343168   10172       666           2146
# 4       2095731  132235      1989          17518
# ...         ...     ...       ...            ...
# 40944   1685609   38160      1385           2657
# 40945   1064798   60008       382           3936
# 40946   1066451   48068      1032           3992
# 40947   5660813  192957      2846          13088
# 40948  10306119  357079    212976         144795
#
# [40949 rows x 4 columns]

# %%
videos_restrict.corr()
# Out:
#                   views     likes  dislikes  comment_count
# views          1.000000  0.849177  0.472213       0.617621
# likes          0.849177  1.000000  0.447186       0.803057
# dislikes       0.472213  0.447186  1.000000       0.700184
# comment_count  0.617621  0.803057  0.700184       1.000000

# %%
plt.imshow(videos_restrict.corr(),clim=(-1,1), cmap='RdBu')
plt.xticks([0,1,2,3],['views', 'likes', 'dislikes', 'comment_count']);
plt.yticks(range(len(videos_restrict.columns)), videos_restrict.columns, rotation=45)
plt.colorbar()
