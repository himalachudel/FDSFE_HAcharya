# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import scipy as scy

# %%
import scipy.stats as stats

# %% [markdown]
# **Let 'happiness_rough' be the name of dataframe imported from the given raw data**

# %%
happiness_rough=pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/main/data/happines.csv",)

# %%
happiness_noindex=pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/main/data/happines.csv",index_col=0)

# %%
happiness_rough
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
# 158      Namibia                              NaN            4.639
# 159       Gambia                              NaN            4.516
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# **Some rows have missing values, so they are being omitted here.Let 'happiness' be the name of dataframe after dropping NaN values**

# %%
happiness=happiness_rough.dropna()

# %%
happiness
# Out:
#          Country                           Region  Happiness Score  \
# 0    Switzerland                   Western Europe            7.587
# 1        Iceland                   Western Europe            7.561
# 2        Denmark                   Western Europe            7.527
# 3         Norway                   Western Europe            7.522
# 4         Canada                    North America            7.427
# ..           ...                              ...              ...
# 153       Rwanda               Sub-Saharan Africa            3.465
# 154        Benin               Sub-Saharan Africa            3.340
# 155        Syria  Middle East and Northern Africa            3.006
# 156      Burundi               Sub-Saharan Africa            2.905
# 157         Togo               Sub-Saharan Africa            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
happiness.shape
# Out:
# (158, 12)

# %% [markdown]
# TARA - Next time, Make sure to explore the characteristics of your dataset before dropping any values.

# %%
happiness.head(10)
# Out:
#        Country                     Region  Happiness Score  Standard Error  \
# 0  Switzerland             Western Europe            7.587         0.03411
# 1      Iceland             Western Europe            7.561         0.04884
# 2      Denmark             Western Europe            7.527         0.03328
# 3       Norway             Western Europe            7.522         0.03880
# 4       Canada              North America            7.427         0.03553
# 5      Finland             Western Europe            7.406         0.03140
# 6  Netherlands             Western Europe            7.378         0.02799
# 7       Sweden             Western Europe            7.364         0.03157
# 8  New Zealand  Australia and New Zealand            7.286         0.03371
# 9    Australia  Australia and New Zealand            7.284         0.04083
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
happiness.tail(10)
# Out:
#           Country                           Region  Happiness Score  \
# 148          Chad               Sub-Saharan Africa            3.667
# 149        Guinea               Sub-Saharan Africa            3.656
# 150   Ivory Coast               Sub-Saharan Africa            3.655
# 151  Burkina Faso               Sub-Saharan Africa            3.587
# 152   Afghanistan                    Southern Asia            3.575
# 153        Rwanda               Sub-Saharan Africa            3.465
# 154         Benin               Sub-Saharan Africa            3.340
# 155         Syria  Middle East and Northern Africa            3.006
# 156       Burundi               Sub-Saharan Africa            2.905
# 157          Togo               Sub-Saharan Africa            2.839
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 148         0.03830                   0.34193  0.76062
# 149         0.03590                   0.17417  0.46475
# ...

# %% [markdown]
# **Below are the statistical properties of different colums of the dataframe**

# %%
happiness.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# **Finding out which one is the happiest country**

# %%
happiness[happiness["Happiness Score"]==happiness["Happiness Score"].max()]
# Out:
#        Country          Region  Happiness Score  Standard Error  \
# 0  Switzerland  Western Europe            7.587         0.03411
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  1.34951                   0.94143  0.66557
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 0                        0.41978     0.29678            2.51738  2015

# %% [markdown]
# **Switzerland is the happiest country**

# %% [markdown]
# **Now I am locating a country of my choice 'NEPAL' from index ommitted dataframe "happpiness_noindex" and finding its Happiness Score**

# %%
happiness_noindex.loc["Nepal"]
# Out:
# Region                           Southern Asia
# Happiness Score                          4.514
# Standard Error                         0.03607
# Economy (GDP per Capita)               0.35997
# Family                                 0.86449
# Health (Life Expectancy)               0.56874
# Freedom                                0.38282
# Trust (Government Corruption)          0.05907
# Generosity                             0.32296
# Dystopia Residual                      1.95637
# year                                      2015
# Name: Nepal, dtype: object

# %% [markdown]
# **Happiness Score of my country of choice 'Nepal' is 4.514**

# %% [markdown]
# **Finding out whether the happiest country is first ranked in other variable as well or not**

# %%
happiness[happiness["Economy (GDP per Capita)"]==happiness["Economy (GDP per Capita)"].max()]
# Out:
#    Country                           Region  Happiness Score  Standard Error  \
# 27   Qatar  Middle East and Northern Africa            6.611         0.06257
#
#     Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 27                   1.69042  1.0786                   0.79733   0.6404
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 27                        0.52208     0.32573            1.55674  2015

# %% [markdown]
# **Qatar but not Switzerland has the highest Economy**

# %%
happiness[happiness["Family"]==happiness["Family"].max()]
# Out:
#    Country          Region  Happiness Score  Standard Error  \
# 1  Iceland  Western Europe            7.561         0.04884
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 1                   1.30232  1.40223                   0.94784  0.62877
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 1                        0.14145      0.4363            2.70201  2015

# %% [markdown]
# **Iceland but not Switzerland has the highest family index**

# %%
happiness[happiness["Health (Life Expectancy)"]==happiness["Health (Life Expectancy)"].max()]
# Out:
#       Country             Region  Happiness Score  Standard Error  \
# 23  Singapore  Southeastern Asia            6.798          0.0378
#
#     Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 23                   1.52186    1.02                   1.02525  0.54252
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 23                         0.4921     0.31105            1.88501  2015

# %% [markdown]
# **Singapore but not Switzerland has the highest life expectancy**

# %%
happiness[happiness["Freedom"]==happiness["Freedom"].max()]
# Out:
#   Country          Region  Happiness Score  Standard Error  \
# 3  Norway  Western Europe            7.522          0.0388
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 3                     1.459  1.33095                   0.88521  0.66973
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 3                        0.36503     0.34699            2.46531  2015

# %% [markdown]
# **Norway but not Switzerland is the most free country**

# %%
happiness[happiness["Trust (Government Corruption)"]==happiness["Trust (Government Corruption)"].max()]
# Out:
#     Country              Region  Happiness Score  Standard Error  \
# 153  Rwanda  Sub-Saharan Africa            3.465         0.03464
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# 153                   0.22208  0.7737                   0.42864  0.59201
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 153                        0.55191     0.22628            0.67042  2015

# %% [markdown]
# **Rwanda but not Switzerland is the most corrupt country**

# %%
happiness[happiness["Generosity"]==happiness["Generosity"].max()]
# Out:
#      Country             Region  Happiness Score  Standard Error  \
# 128  Myanmar  Southeastern Asia            4.307         0.04351
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 128                   0.27108  0.70905                   0.48246  0.44017
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 128                        0.19034     0.79588            1.41805  2015

# %% [markdown]
# **Myanmar but not Switzerland is the most generous country**

# %%
happiness[happiness["Dystopia Residual"]==happiness["Dystopia Residual"].max()]
# Out:
#    Country                       Region  Happiness Score  Standard Error  \
# 13  Mexico  Latin America and Caribbean            7.187         0.04176
#
#     Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 13                   1.02054  0.91451                   0.81444  0.48181
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual  year
# 13                        0.21312     0.14074            3.60214  2015

# %% [markdown]
# **Mexico but not Switzerland has high dystopial residue**

# %% [markdown]
# **By runnining above indexes, it has been concluded that the happiest country "Switzerland" is not the top country in other variables such as GDP, Family health, Freedom, etc**

# %% [markdown]
# **Let happiness_hs be the new dataframne formed by sorting happiness dataframe with Happiness Score**

# %%
happiness_hs=happiness.sort_values(["Happiness Score"],ascending=[False])

# %%
happiness_hs.head(10)
# Out:
#        Country                     Region  Happiness Score  Standard Error  \
# 0  Switzerland             Western Europe            7.587         0.03411
# 1      Iceland             Western Europe            7.561         0.04884
# 2      Denmark             Western Europe            7.527         0.03328
# 3       Norway             Western Europe            7.522         0.03880
# 4       Canada              North America            7.427         0.03553
# 5      Finland             Western Europe            7.406         0.03140
# 6  Netherlands             Western Europe            7.378         0.02799
# 7       Sweden             Western Europe            7.364         0.03157
# 8  New Zealand  Australia and New Zealand            7.286         0.03371
# 9    Australia  Australia and New Zealand            7.284         0.04083
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %% [markdown]
# **Thus abovementioned Switzerland, Iceland, Denmark, Norway, Canada, Finland, Netherlands, Sweden, New Zealand, Australia are the top ten happiest countries**

# %% [markdown]
# **Let 'happiness_new' be the name of dataframe having all numberic and float entries**

# %%
happiness_new=happiness[['Happiness Score','Standard Error','Economy (GDP per Capita)','Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)','Generosity','Dystopia Residual']]

# %%
happiness_new.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
plt.imshow(happiness_new.corr(), clim=(-1,1), cmap="RdBu")
plt.xticks([0,1,2,3,4,5,6,7,8], ['Happiness Score','Standard Error','Economy (GDP per Capita)',
                       'Family','Health (Life Expectancy)','Freedom','Trust (Government Corruption)',
                       'Generosity','Dystopia Residual'],rotation=90);
plt.yticks(range(len(happiness_new.columns)), happiness_new.columns, rotation=45);
plt.colorbar()

# %% [markdown]
# **The graph above shows the correlation between 9 numeric variables. Colors range from red to blue, red showing negative correlation and blue showing postive correlation. The diagonal boxes from top left to bottom right corner show the highest correlation of 1**

# %%
happiness_generosity=happiness.groupby("Region")

# %%
happiness.groupby("Region").mean()
# Out:
# <ipython-input-462-87762ac1fc8b>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   happiness.groupby("Region").mean()
#                                  Happiness Score  Standard Error  \
# Region
# Australia and New Zealand               7.285000        0.037270
# Central and Eastern Europe              5.332931        0.045208
# Eastern Asia                            5.626167        0.037225
# Latin America and Caribbean             6.144682        0.061127
# Middle East and Northern Africa         5.406900        0.046337
# North America                           7.273000        0.036960
# Southeastern Asia                       5.317444        0.042691
# Southern Asia                           4.580857        0.032161
# Sub-Saharan Africa                      4.202800        0.055299
# ...

# %% [markdown]
# **The Australia and New Zealand has the highest generosity**

# %% [markdown]
# **Now moving ahead with KS test**

# %%
stats.ks_2samp(happiness["Generosity"],happiness["Generosity"])
# Out:
# KstestResult(statistic=0.0, pvalue=1.0, statistic_location=0.0, statistic_sign=1)

# %% [markdown]
# **The P value of 1.0 is way higher than 0.05 at 95% CI. Thus null hypothesis is thus not rejected. The reason for the highest value possible of p is  because we are trying to compare two same distribution of values.**

# %%
stats.ks_2samp(happiness["Happiness Score"],happiness["Economy (GDP per Capita)"])
# Out:
# KstestResult(statistic=1.0, pvalue=3.340399673037736e-94, statistic_location=1.69042, statistic_sign=-1)

# %% [markdown]
# **The P value of 3.34X10^-94 is way smaller than 0.05 at 95% CI. Thus null hypothesis is rejected.**
